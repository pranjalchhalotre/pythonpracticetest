# %%
# Practice set - 1 (31st Jan 26)

# %%
# arithmatic operator

# %%
print(10+5*2)
# Out:
# 20

# %%
print((10+5)*2)
# Out:
# 30

# %%
a= 20
b=4
c =2
print(a-b**2)
# Out:
# 4

# %%
print(100//5*2)
# Out:
# 40

# %%
print(18 % 5+2)
# Out:
# 5

# %%
a=2
b=3
c=2
print(a**b**c)
# Out:
# 512

# %%
a=4
b=2
c=3
print(a*b**c)
# Out:
# 32

# %%
a=16
b=2

print(a//b**c)
# Out:
# 4

# %%
print(9+6*2**2)
# Out:
# 33

# %%
print(8-2**2*2)
# Out:
# 0

# %%
# logical operator

# %%
print(10>5 and 5>2)
# Out:
# True

# %%
print(10>5 or 5<2)
# Out:
# True

# %%
print(not 10>5)
# Out:
# False

# %%
print(True or False and False)
# Out:
# True

# %%
print(5<10<20)
# Out:
# True

# %%
x =5
x +=3*2
print(x)
# Out:
# 11

# %%
x =10
x *=2+3
print(x)
# Out:
# 50

# %%
x= 5
x=x==5
print(x)
# Out:
# True

# %%
x=2
x **= 2+1
print(x)
# Out:
# 8

# %%
x= 1
x+=x==1
print(x)
# Out:
# 2

# %%
print(5 and 0 or 8)
# Out:
# 8

# %%
print(0 or 5 and 8)
# Out:
# 8

# %%
print(True == False or True)
# Out:
# True

# %%
print(False == False or False)
# Out:
# True

# %%
print( not True == False)
# Out:
# True

# %%
#1 (membership operator)
a = input("enter your char:")
str = "hello"
if a in str:
    print( " yes",a," present in str:")
else:
    print("not present")
# Out:
# enter your char: h
#  yes h  present in str:

# %%
#2
a = int(input("enter your char:"))
str = [2,3,5,7,11]
if a in str:
    print( a," is a prime number :")
else:
    print("not present")
# Out:
# enter your char: 8
# not present

# %%
#3
a = (input("enter your char:"))
str = ["john123","alice","bob"]
if a in str:
    print( a," already taken :")
else:
    print("not present")
# Out:
# enter your char: john123
# john123  already taken :

# %%
#4
a = (input("enter your char:"))
str = ["john123","alice","bob"]
if a in str:
    print( a," already taken :")
else:
    print("not present")

# %%
#5
str =input("enter your str:")
word = input("enter your word:")
if word in str:
    print(word,"is present in the sentence:")
else:
    print("not present")
# Out:
# enter your str: the sun rises in the east
# enter your word: sun
# sun is present in the sentence:

# %%
#6
cart = ["bread","eggs"]
item = input("enter item:")
if item in cart:
    print(item,"it is alredy present")
else:
    print(item,"is not present .Add now")
# Out:
# enter item: milk
# milk is not present .Add now

# %%
# identity operators

# %%
#1
a = [1,2]
b =a
if a is b:
    print("a and b refer to same object:")
else:
    print("not same object")
# Out:
# a and b refer to same object:

# %%
#2
list1 = input("enter your list")
list2 = input ("enter your list")
if list1==list2:
    print("refer to same object")
     
else:
    print("list1 and list2 do not refer to the same object:")
# Out:
# enter your list 1,2,3
# enter your list 3,4,5
# list1 and list2 do not refer to the same object:

# %%
#3
var = None
if var is None:
    print("the variable is None")
# Out:
# the variable is None

# %%
#4
var = input("enter str:")
if var is not  None:
    print("the variable is None.")
else:
    print("varirable is not none.")
# Out:
# enter str: hello
# the variable is None.

# %%
#5
str1 = "apple"
str2 =["a","p","p","l","e",]

if str1 in str2:
    print("str1 and str2 are have same value but not same object :")
else:
    print("diffrent value")
# Out:
# diffrent value

# %%
#5
a ="apple"
b = ["h","p","p","l","e"]
count =0
for i in a:
    if i in b:
        count = count+1
if count==len(b):
    print("same value,diffrent obj")
else:
    print("diff")
# Out:
# diff
