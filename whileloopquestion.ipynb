# %%
"""1, Print all odd numbers between 10 and 30 and calculate their sum
2, Find the sum of digits of a given number
3, Reverse a given number using a while loop.
4, Check if a number is a palindrome using a while loop.
5, Check if a number is an Armstrong number using a while loop.
6, Count the number of factors of a number using a while loop
7, Find the largest digit in a given number using a while loop.
8, Find the smallest digit in a number using a while loop.
9, Count how many times a given digit appears in a number using a while loop
10, Generate the Fibonacci series up to N terms using a while loop"""

# %%
#, Print all odd numbers between 10 and 30 and calculate their sum
i= 10
sum_num=0
while i<=30:
    if i%2 !=0:
        sum_num+=1
        print(i)
    i=i+1
print("sum of odd number is:",sum_num)

# %%
#Find the sum of digits of a given number
i =int(input("enter number"))
sum_num =0
count =i

while count>0:
    digit = count % 10
    sum_num += digit
    count =count //10
print(sum_num)
# Out:
# enter number 1234
# 10

# %%
#Reverse a given number using a while loop.
num = int(input("enter number:"))
reverse =0 
while num >0:
    digit = num % 10
    reverse = reverse*10+digit
    num //=10
print("Reversed number:",reverse)
# Out:
# enter number: 1234
# Reversed number: 4321

# %%
#Check if a number is a Armstrong using a while loop.
num = int(input("enter number"))
temp = num
sum =0
digits =0
t =num 
while t>0:
    digits +=1
    t//= 10
while temp>0:
    digit = temp % 10
    sum +=digit ** digits
    temp //=10
if sum == num:
    print(num,"is an Armstrong number")
else:
    print(num,"is not an Armstrong number")
# Out:
# enter number 153
# 153 is an Armstrong number

# %%
#Check if a number is a palindrome using a while loop.
num = int(input("Enter a number: "))
temp = num
rev = 0

while temp > 0:
    digit = temp % 10
    rev = rev * 10 + digit
    temp //= 10

if rev == num:
    print(num, "is a palindrome number")
else:
    print(num, "is not a palindrome number")
# Out:
# Enter a number:  121
# 121 is a palindrome number

# %%
#Count the number of factors of a number using a while loop
num = int(input("Enter a number: "))
i = 1
count = 0

while i <= num:
    if num % i == 0:
        count += 1
    i += 1

print("Number of factors:",count)
# Out:
# Enter a number:  5
# Number of factors: 2

# %%
#Find the largest digit in a given number using a while loop.
num = int(input("Enter a number: "))
largest = 0

while num > 0:
    digit = num % 10
    if digit > largest:
        largest = digit
    num //= 10

print("Largest digit:", largest)
# Out:
# Enter a number:  2345
# Largest digit: 5

# %%
#Find the smallest digit in a number using a while loop.
num = int(input("Enter a number: "))
smallest = 9

while num > 0:
    digit = num % 10
    if digit < smallest:
        smallest = digit
    num //= 10

print("Smallest digit:", smallest)
# Out:
# Enter a number:  234
# Smallest digit: 2

# %%
#Fibonacci series up to N terms using a while loop
n = int(input("Enter number of terms: "))

a = 0
b = 1
count = 0

while count < n:
    print(a, end=" ")
    c = a + b
    a = b
    b = c
    count += 1
# Out:
# Enter number of terms:  6
# 0 1 1 2 3 5

# %%
#how many times a given digit appears in a number using a while loop
num = int(input("Enter a number: "))
digit_to_count = int(input("Enter the digit to count: "))

count = 0

while num > 0:
    digit = num % 10
    if digit == digit_to_count:
        count += 1
    num //= 10

print("Digit", digit_to_count, "appears", count, "times")
# Out:
# Enter a number:  1123344
# Enter the digit to count:  4
# Digit 4 appears 2 times
