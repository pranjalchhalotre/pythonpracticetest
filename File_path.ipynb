# %%
import os
cwd=os.getcwd()
print(f"current working directing is {cwd}")
# Out:
# current working directing is C:\Users\Pranjal chhalotre\OneDrive\Desktop\python_class

# %%
new_directory ="package1"
os.mkdir(new_directory)
print(f"directory'{new_directory}'create")
# Out:
# directory'package1'create

# %%
items=os.listdir('.')
print(items)
# Out:
# ['.ipynb_checkpoints', 'data.txt', 'example.txt', 'Exception Handling.ipynb', 'FileHandling.ipynb', 'Functions.ipynb', 'Lembdafunction.ipynb', 'package1', 'practisetest.ipynb', 'practisetest7march.ipynb', 'python.txt', 'pythonclass', 'pythonclass.ipynb', 'pythonquestion.ipynb', 'Untitled.ipynb', 'whileloopquestion.ipynb']
