# %%
file_location = "C:\\Users\\Pranjal chhalotre\\OneDrive\\Desktop\\python_class"
file_name ="example"
extension=".txt"

# %%
file_path="C:\\Users\\Pranjal chhalotre\\OneDrive\\Desktop\\python_class\\example.txt"

# %%
open(file_path)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Pranjal chhalotre\\OneDrive\\Desktop\\python_class\\example.txt' mode='r' encoding='cp1252'>

# %%
file=open(file_path,"r")
file.read()
# Out:
# 'Hello, my name is pranjal chhalotre\ntodays topic is File Handling.'

# %%
with open('example.txt','r')as file:
    print(file.read())
# Out:
# Hello, my name is pranjal chhalotre
# todays topic is File Handling.

# %%
with open('example.txt','r')as f:
    print(f.read(10))
    print(f.readline())
    print(f.readline())
# Out:
# Hello, my
# name is pranjal chhalotre
#
# todays topic is File Handling.

# %%
with open('example.txt','r')as file:
    for i in file:
        print(i.strip())
# Out:
# Hello, my name is pranjal chhalotre
# todays topic is File Handling.

# %%
with open('example.txt','a')as file:
    file.write("append operation taking place!\n")
with open("example.txt",'r')as f:
    print(f.read())
# Out:
# Hello, my name is pranjal chhalotre
# todays topic is File Handling.append operation taking placeappend operation taking place!

# %%
lines =[
    file.write(lines)
with open("example.txt",'r')as f:
    print(f.read())

# %%
#write
with open("data.txt","w") as f:
    f.write("Hello")

# %%
#writelines()
lines = ["Hello\n","Python\n","World"]

with open("data.txt","w") as f:
    f.writelines(lines)

# %%
#get cwd to get current directories.
